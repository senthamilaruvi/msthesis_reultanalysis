# %%
# %matplotlib inline

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from numpy import arange

# %%
os.chdir('E:\Academics\Research\Data\Experimental data\Compression_test\Results')
P1 = pd.read_excel('P002_B001_Area.xlsx')
list(P1)
# Out:
# [u'Samples',
#  u'Phi',
#  u'Theta',
#  u'Minimum Pixel count',
#  u'Pixel Size',
#  u'Minimum Area',
#  'Unnamed: 6']

# %%
P2 = P1[P1['Phi']== 0]
P3 = P1[P1['Phi']== 45]
P4 = P1[P1['Phi']== 90]

# %%
fig = plt.figure(figsize=(14,7))

fig.subplots_adjust(hspace=.5)

fig.suptitle("Distribution_of_area", fontsize=16)

ax1 = fig.add_subplot(131)
ax1.hist(P1['Minimum Area'], bins = 6)
ax1.set_xlabel('Area', fontsize = 12)
ax1.set_ylabel('Frequency', fontsize = 12)

ax2 = fig.add_subplot(132)
ax2.hist(P5['Minimum Area'], bins =6)
ax2.set_xlabel('Area', fontsize = 12)
ax2.set_ylabel('Frequency', fontsize = 12)

ax3 = fig.add_subplot(133)
ax3.hist(P5['Minimum Area'], bins =6)
ax3.set_xlabel('Area', fontsize = 12)
ax3.set_ylabel('Frequency', fontsize = 12)

# %%
fig.savefig('C:\Users\senth\Desktop\Histograms\Tensile_Heattreated.jpg')
